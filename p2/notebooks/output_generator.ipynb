# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
ids_scenario1 = pd.read_csv("/content/drive/MyDrive/P2/data/raw/scenario01/csv/patients.csv", index_col=None, header=None)
ids_scenario2 = pd.read_csv("/content/drive/MyDrive/P2/data/raw/scenario02/csv/patients.csv", index_col=None, header=None)

results7_1_1 = pd.read_csv("/content/drive/MyDrive/P2/results/results7_1_1.csv" , index_col=None, header=None)
results15_1_1 = pd.read_csv("/content/drive/MyDrive/P2/results/results15_1_1.csv" , index_col=None, header=None)
results7_2_2 = pd.read_csv("/content/drive/MyDrive/P2/results/results7_2_2.csv" , index_col=None, header=None)
results15_2_2 = pd.read_csv("/content/drive/MyDrive/P2/results/results15_2_2.csv" , index_col=None, header=None)

# %%
ids_scenario1.head()
# Out:
#                                      0           1           2            3   \
# 0                                    Id   BIRTHDATE   DEATHDATE          SSN
# 1  7b3c738d-3f86-58e3-450e-4018521d192f  2021-08-11         NaN  999-71-7790
# 2  c40c2c75-13c9-8e4a-047f-573ae1330157  2020-03-03         NaN  999-49-5505
# 3  39e76039-522c-61f1-d961-e03dce5f0bb2  1998-11-21  2003-07-17  999-36-5991
# 4  ff981e00-4004-44b4-48ba-0bfa62440bb3  2009-07-29         NaN  999-39-5303
#
#         4         5       6             7                8       9   ...  \
# 0  DRIVERS  PASSPORT  PREFIX         FIRST             LAST  SUFFIX  ...
# 1      NaN       NaN     NaN   Svetlana462        O'Hara248     NaN  ...
# 2      NaN       NaN     NaN    Rosalyn434  Christiansen251     NaN  ...
# 3      NaN       NaN     NaN  Lashawnda573        Daniel959     NaN  ...
# 4      NaN       NaN     NaN    Ulysses632          Rice937     NaN  ...
#
# ...

# %%
ids_alive_scenario1 = ids_scenario1[ids_scenario1[2].isna()]
ids_alive_scenario1 = ids_alive_scenario1[0]
ids_alive_scenario1.head()
len(ids_alive_scenario1)
# Out:
# 1000

# %%
results7_1_1.head()
# Out:
#                                       0                    1  \
# 0                            Id_patient  Logistic Regression
# 1                                string           False True
# 2                                  meta                 meta
# 3  114f35cc-db2d-65d7-678b-18495e4e6473                 True
# 4  929d7327-052c-e985-7823-b7258efbe344                 True
#
#                              2                           3
# 0  Logistic Regression (False)  Logistic Regression (True)
# 1                   continuous                  continuous
# 2                         meta                        meta
# 3           0.3767119883019757          0.6232880116980243
# 4          0.19183788408036728          0.8081621159196327

# %%
results15_1_1.head()
# Out:
#                                       0                    1  \
# 0                            Id_patient  Logistic Regression
# 1                                string           False True
# 2                                  meta                 meta
# 3  114f35cc-db2d-65d7-678b-18495e4e6473                 True
# 4  929d7327-052c-e985-7823-b7258efbe344                 True
#
#                              2                           3
# 0  Logistic Regression (False)  Logistic Regression (True)
# 1                   continuous                  continuous
# 2                         meta                        meta
# 3           0.3767119883019757          0.6232880116980243
# 4          0.19183788408036728          0.8081621159196327

# %%
results7_1_1.drop([1,2],axis=0,inplace=True)
results15_1_1.drop([1,2],axis=0,inplace=True)
results7_1_1.head()
# Out:
#                                       0                    1  \
# 0                            Id_patient  Logistic Regression
# 3  114f35cc-db2d-65d7-678b-18495e4e6473                 True
# 4  929d7327-052c-e985-7823-b7258efbe344                 True
# 5  ec45c9d5-774d-84b1-2f1f-e0bc20c9c722                False
# 6  b9e01fd8-1d11-b29f-01c1-d481d5476496                False
#
#                              2                           3
# 0  Logistic Regression (False)  Logistic Regression (True)
# 3           0.3767119883019757          0.6232880116980243
# 4          0.19183788408036728          0.8081621159196327
# 5           0.7351399783862966          0.2648600216137034
# 6           0.9999999999983858      1.6141854129036575e-12

# %%
results15_1_1.head()
# Out:
#                                       0                    1  \
# 0                            Id_patient  Logistic Regression
# 3  114f35cc-db2d-65d7-678b-18495e4e6473                 True
# 4  929d7327-052c-e985-7823-b7258efbe344                 True
# 5  ec45c9d5-774d-84b1-2f1f-e0bc20c9c722                False
# 6  b9e01fd8-1d11-b29f-01c1-d481d5476496                False
#
#                              2                           3
# 0  Logistic Regression (False)  Logistic Regression (True)
# 3           0.3767119883019757          0.6232880116980243
# 4          0.19183788408036728          0.8081621159196327
# 5           0.7351399783862966          0.2648600216137034
# 6           0.9999999999983858      1.6141854129036575e-12

# %%
combination7_1_1 = results7_1_1[results7_1_1[0].isin(ids_alive_scenario1)]
combination7_1_1.head()
# Out:
#                                       0      1                   2  \
# 3  114f35cc-db2d-65d7-678b-18495e4e6473   True  0.3767119883019757
# 5  ec45c9d5-774d-84b1-2f1f-e0bc20c9c722  False  0.7351399783862966
# 6  b9e01fd8-1d11-b29f-01c1-d481d5476496  False  0.9999999999983858
# 8  a182e9e8-ca76-85fe-18f1-3c747b4750f9  False                 1.0
# 9  9247e723-c35b-dc98-3071-b908dc425ab6  False                 1.0
#
#                          3
# 3       0.6232880116980243
# 5       0.2648600216137034
# 6   1.6141854129036575e-12
# 8   2.967763180103652e-227
# 9  3.1355799251392274e-218

# %%
len(combination7_1_1)
# Out:
# 677

# %%
combination15_1_1 = results15_1_1[results15_1_1[0].isin(ids_alive_scenario1)]
combination15_1_1.head()
# Out:
#                                       0      1                   2  \
# 3  114f35cc-db2d-65d7-678b-18495e4e6473   True  0.3767119883019757
# 5  ec45c9d5-774d-84b1-2f1f-e0bc20c9c722  False  0.7351399783862966
# 6  b9e01fd8-1d11-b29f-01c1-d481d5476496  False  0.9999999999983858
# 8  a182e9e8-ca76-85fe-18f1-3c747b4750f9  False                 1.0
# 9  9247e723-c35b-dc98-3071-b908dc425ab6  False                 1.0
#
#                          3
# 3       0.6232880116980243
# 5       0.2648600216137034
# 6   1.6141854129036575e-12
# 8   2.967763180103652e-227
# 9  3.1355799251392274e-218

# %%
len(combination15_1_1)
# Out:
# 677

# %%
column_names = ["IdPaciente", "Probabilidade_7d", "Probabilidade_15d"]
alive_1_1 = pd.DataFrame(columns = column_names)

# %%
combination7_1_1.reset_index(inplace=True)
alive_1_1["IdPaciente"] = combination7_1_1[0]
var = [combination7_1_1.loc[i,3]  if combination7_1_1.loc[i, 1] == True else combination7_1_1.loc[i, 2] for i in range(len(combination7_1_1))]
alive_1_1["Probabilidade_7d"] = pd.Series(var)
#output.assign(probabilidade=var)
#output[1] =  [combination1.loc[i,4]  if combination1.loc[i, 2] == True else combination1.loc[i, 3] for i in range(len(combination1)) ]

# %%
combination15_1_1.reset_index(inplace=True)
var1 = [combination15_1_1.loc[i,3]  if combination15_1_1.loc[i, 1] == True else combination15_1_1.loc[i, 2] for i in range(len(combination15_1_1))]
alive_1_1["Probabilidade_15d"] = pd.Series(var1)

# %%
alive_1_1.head()
# Out:
#                              IdPaciente    Probabilidade_7d  \
# 0  114f35cc-db2d-65d7-678b-18495e4e6473  0.3767119883019757
# 1  ec45c9d5-774d-84b1-2f1f-e0bc20c9c722  0.7351399783862966
# 2  b9e01fd8-1d11-b29f-01c1-d481d5476496  0.9999999999983858
# 3  a182e9e8-ca76-85fe-18f1-3c747b4750f9                 1.0
# 4  9247e723-c35b-dc98-3071-b908dc425ab6                 1.0
#
#     Probabilidade_15d
# 0  0.3767119883019757
# 1  0.7351399783862966
# 2  0.9999999999983858
# 3                 1.0
# 4                 1.0

# %%
alive_1_1.to_csv('/content/drive/MyDrive/P2/results/output_1_1.csv')

# %%
ids_scenario2.head()
# Out:
#                                      0           1          2            3   \
# 0                                    Id   BIRTHDATE  DEATHDATE          SSN
# 1  623336a5-3e7b-57c7-dbd3-b77434c1e1c7  2022-04-22        NaN  999-59-7348
# 2  bb37561b-ba65-7c47-db5b-0641bca883b4  2012-02-08        NaN  999-16-2180
# 3  62fc8f1c-cbca-4143-bcda-8075dd42eaf0  2009-09-07        NaN  999-89-5507
# 4  678fc07c-1cb1-acc6-3553-d848200626e9  2006-02-11        NaN  999-92-8411
#
#           4         5       6           7                8       9   ...  \
# 0    DRIVERS  PASSPORT  PREFIX       FIRST             LAST  SUFFIX  ...
# 1        NaN       NaN     NaN    Jesse626          Rowe323     NaN  ...
# 2        NaN       NaN     NaN     Noah480       Leffler128     NaN  ...
# 3        NaN       NaN     NaN  Woodrow571         Koepp521     NaN  ...
# 4  S99990200       NaN     NaN   Odessa199  Pfannerstill264     NaN  ...
#
#                       15                       16      17      18  \
# ...

# %%
ids_alive_scenario2 = ids_scenario2[ids_scenario2[2].isna()]
ids_alive_scenario2 = ids_alive_scenario2[0]
ids_alive_scenario2.head()
len(ids_alive_scenario2)
# Out:
# 1000

# %%
results7_2_2.head()
# Out:
#                                       0                    1  \
# 0                            Id_patient  Logistic Regression
# 1                                string           False True
# 2                                  meta                 meta
# 3  c756039f-7e98-f161-edc9-1bdc1eaf6ed8                False
# 4  42daadf8-8681-84f0-de32-b34b43da4366                False
#
#                              2                           3
# 0  Logistic Regression (False)  Logistic Regression (True)
# 1                   continuous                  continuous
# 2                         meta                        meta
# 3           0.9999608979963647      3.9102003635286495e-05
# 4           0.5505898941602541         0.44941010583974594

# %%
results15_2_2.head()
# Out:
#                                       0                    1  \
# 0                            Id_patient  Logistic Regression
# 1                                string           False True
# 2                                  meta                 meta
# 3  c756039f-7e98-f161-edc9-1bdc1eaf6ed8                False
# 4  42daadf8-8681-84f0-de32-b34b43da4366                False
#
#                              2                           3
# 0  Logistic Regression (False)  Logistic Regression (True)
# 1                   continuous                  continuous
# 2                         meta                        meta
# 3           0.9999437496961082      5.6250303891823786e-05
# 4           0.5678619453093301         0.43213805469066996

# %%
results7_2_2.drop([1,2],axis=0,inplace=True)
results15_2_2.drop([1,2],axis=0,inplace=True)
results7_2_2.head()
# Out:
#                                       0                    1  \
# 0                            Id_patient  Logistic Regression
# 3  c756039f-7e98-f161-edc9-1bdc1eaf6ed8                False
# 4  42daadf8-8681-84f0-de32-b34b43da4366                False
# 5  f7fd6901-659d-9dc9-4e20-e5ca1420e61f                False
# 6  572f7c22-600f-501f-6470-e355f3fdff57                 True
#
#                              2                           3
# 0  Logistic Regression (False)  Logistic Regression (True)
# 3           0.9999608979963647      3.9102003635286495e-05
# 4           0.5505898941602541         0.44941010583974594
# 5           0.9999926371230122       7.362876987790146e-06
# 6          0.25171835790697683          0.7482816420930232

# %%
results15_2_2.head()
# Out:
#                                       0                    1  \
# 0                            Id_patient  Logistic Regression
# 3  c756039f-7e98-f161-edc9-1bdc1eaf6ed8                False
# 4  42daadf8-8681-84f0-de32-b34b43da4366                False
# 5  f7fd6901-659d-9dc9-4e20-e5ca1420e61f                False
# 6  572f7c22-600f-501f-6470-e355f3fdff57                 True
#
#                              2                           3
# 0  Logistic Regression (False)  Logistic Regression (True)
# 3           0.9999437496961082      5.6250303891823786e-05
# 4           0.5678619453093301         0.43213805469066996
# 5           0.9999985097400641      1.4902599359316143e-06
# 6          0.20294319770431046          0.7970568022956895

# %%
combination7_2_2 = results7_2_2[results7_2_2[0].isin(ids_alive_scenario2)]
combination7_2_2.head()
# Out:
#                                       0      1                    2  \
# 3  c756039f-7e98-f161-edc9-1bdc1eaf6ed8  False   0.9999608979963647
# 4  42daadf8-8681-84f0-de32-b34b43da4366  False   0.5505898941602541
# 5  f7fd6901-659d-9dc9-4e20-e5ca1420e61f  False   0.9999926371230122
# 6  572f7c22-600f-501f-6470-e355f3fdff57   True  0.25171835790697683
# 7  dccb9c38-44cd-68c5-852c-e63a0b035a4f  False   0.9999657784275652
#
#                         3
# 3  3.9102003635286495e-05
# 4     0.44941010583974594
# 5   7.362876987790146e-06
# 6      0.7482816420930232
# 7  3.4221572434848915e-05

# %%
len(combination7_2_2)
# Out:
# 689

# %%
combination15_2_2 = results15_2_2[results15_2_2[0].isin(ids_alive_scenario2)]
combination15_2_2.head()
# Out:
#                                       0      1                    2  \
# 3  c756039f-7e98-f161-edc9-1bdc1eaf6ed8  False   0.9999437496961082
# 4  42daadf8-8681-84f0-de32-b34b43da4366  False   0.5678619453093301
# 5  f7fd6901-659d-9dc9-4e20-e5ca1420e61f  False   0.9999985097400641
# 6  572f7c22-600f-501f-6470-e355f3fdff57   True  0.20294319770431046
# 7  dccb9c38-44cd-68c5-852c-e63a0b035a4f  False   0.9999611296734974
#
#                         3
# 3  5.6250303891823786e-05
# 4     0.43213805469066996
# 5  1.4902599359316143e-06
# 6      0.7970568022956895
# 7  3.8870326502637364e-05

# %%
alive_2_2 = pd.DataFrame(columns = column_names)

# %%
combination7_2_2.reset_index(inplace=True)
alive_2_2["IdPaciente"] = combination7_2_2[0]
var2 = [combination7_2_2.loc[i,3]  if combination7_2_2.loc[i, 1] == True else combination7_2_2.loc[i, 2] for i in range(len(combination7_2_2))]
alive_2_2["Probabilidade_7d"] = pd.Series(var2)

# %%
combination15_2_2.reset_index(inplace=True)
var3 = [combination15_2_2.loc[i,3]  if combination15_2_2.loc[i, 1] == True else combination15_2_2.loc[i, 2] for i in range(len(combination15_2_2))]
alive_2_2["Probabilidade_15d"] = pd.Series(var3)

# %%
alive_2_2.head()
# Out:
#                              IdPaciente     Probabilidade_7d  \
# 0  c756039f-7e98-f161-edc9-1bdc1eaf6ed8   0.9999608979963647
# 1  42daadf8-8681-84f0-de32-b34b43da4366   0.5505898941602541
# 2  f7fd6901-659d-9dc9-4e20-e5ca1420e61f   0.9999926371230122
# 3  572f7c22-600f-501f-6470-e355f3fdff57  0.25171835790697683
# 4  dccb9c38-44cd-68c5-852c-e63a0b035a4f   0.9999657784275652
#
#      Probabilidade_15d
# 0   0.9999437496961082
# 1   0.5678619453093301
# 2   0.9999985097400641
# 3  0.20294319770431046
# 4   0.9999611296734974

# %%
alive_2_2.to_csv('/content/drive/MyDrive/P2/results/output_2_2.csv')
